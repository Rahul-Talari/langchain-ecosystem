# %%
var2=bool(input("Enter the value"))
print(var2)
# Out:
# True

# %%
var=int(input("Enter the value"))
var1=float(input("Enter the value"))
var2=bool(input("Enter the value"))

print(f"Integer value: {var}\nFloat value: {var1:.3f}\nBoolean value: {var2}")  # F-string
# Out:
# Integer value: 3
# Float value: 3.568
# Boolean value: True

# %%
var=int(input("Enter the value"))
print(var)
VAR=int(input("Enter the value"))
print(VAR)
# Out:
# 1
# 1
